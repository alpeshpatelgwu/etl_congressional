# %%
#Define Dependencies need to perfrom ETL
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
#Extract the Olympic data on how athlete's performed
csv_file = "athlete_events.csv"
athlete_events_df = pd.read_csv(csv_file)
athlete_events_df = athlete_events_df[athlete_events_df["Year"] > 2014] 
athlete_events_df.head()
# Out:
#      ID               Name Sex   Age  Height  Weight     Team  NOC  \
# 80   22      Andreea Aanei   F  22.0   170.0   125.0  Romania  ROU
# 139  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 140  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 141  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 142  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
#
#            Games  Year  Season            City          Sport  \
# 80   2016 Summer  2016  Summer  Rio de Janeiro  Weightlifting
# 139  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 140  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 141  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 142  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
#
#                                        Event Medal
# 80   Weightlifting Women's Super-Heavyweight   NaN
# 139   Gymnastics Men's Individual All-Around   NaN
# ...

# %%
#athlete_events_df.dtypes

# %%
athlete_events_df = athlete_events_df[["Team", "Medal"]].copy()
athlete_events_df = athlete_events_df.dropna()
athlete_events_df = athlete_events_df.rename(columns={"Team":"Country"})
athlete_events_df["Country"] = athlete_events_df["Country"].str.strip()
#athlete_events_df = athlete_events_df["Country"].str.strip()

athlete_events_df.head()
# 27116 Rows
# Out:
#         Country   Medal
# 158       Italy  Bronze
# 161  Azerbaijan  Bronze
# 175      France  Silver
# 450        Iran  Bronze
# 794      Russia  Silver

# %%
#Groupby Country and medal

#athlete_events_df = athlete_events_df.groupby(["Country", "Medal"])



#athlete_events_df = pd.DataFrame(athlete_events_df.size().reset_index())

#athlete_events_df

# %%
#athlete_events_df = athlete_events_df.groupby("Country")

#athlete_events_df

# %%
#athlete_events_noc_df.count()

# %%
csv_file = "countries of the world.csv"
countries_df = pd.read_csv(csv_file)
countries_df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
countries_df = countries_df[["Country", "Population", "GDP ($ per capita)"]].copy()
countries_df["GDP ($ per capita)"] = countries_df["GDP ($ per capita)"].map("${:,.2f}".format)
countries_df["Country"] = countries_df["Country"].str.strip()
             
countries_df.head(10)
# Out:
#              Country  Population GDP ($ per capita)
# 0        Afghanistan    31056997            $700.00
# 1            Albania     3581655          $4,500.00
# 2            Algeria    32930091          $6,000.00
# 3     American Samoa       57794          $8,000.00
# 4            Andorra       71201         $19,000.00
# 5             Angola    12127071          $1,900.00
# 6           Anguilla       13477          $8,600.00
# 7  Antigua & Barbuda       69108         $11,000.00
# 8          Argentina    39921833         $11,200.00
# 9            Armenia     2976372          $3,500.00

# %%
# Merge the countries_df to olympic data

#olympics_countries_merged = pd.merge(athlete_events_noc_df, countries_df)

#olympics_countries_merged.head(10)

#olympics_countries_merged.count()

#join = olympics_countries_merged

join_outer = athlete_events_df.merge(countries_df, on="Country")

join_outer
# Out:
#                    Country   Medal  Population GDP ($ per capita)
# 0                    Italy  Bronze    58133509         $26,700.00
# 1                    Italy  Bronze    58133509         $26,700.00
# 2                    Italy  Silver    58133509         $26,700.00
# 3                    Italy  Silver    58133509         $26,700.00
# 4                    Italy    Gold    58133509         $26,700.00
# 5                    Italy    Gold    58133509         $26,700.00
# 6                    Italy  Silver    58133509         $26,700.00
# 7                    Italy  Silver    58133509         $26,700.00
# 8                    Italy  Bronze    58133509         $26,700.00
# 9                    Italy  Silver    58133509         $26,700.00
# 10                   Italy  Silver    58133509         $26,700.00
# 11                   Italy  Bronze    58133509         $26,700.00
# 12                   Italy  Silver    58133509         $26,700.00
# ...

# %%
#join_outer.sort_values(["Medal","GDP ($ per capita)"], ascending=False)

#join_outer.count()

#Drop the NAN values from medals/country data frame

#country_medals_df = athlete_events_noc_df

#country_medals_df = country_medals_df.dropna()

#country_medals_df.index

#list(country_medals_df)

## Delete this
#for i, row in country_medals_df.iterrows():
 #   country = country_medals_df.get_value(i, 'Country')
  #  if country_medals_df.get_value(i, 'Country') == country:
   #     print(f'Yes')
    #    print(f'{country}')

# %%
### This can all get deleted

#grouped_country_df = country_medals_df.groupby("Country")

#grouped_country_df.head()

# %%
grouped_country_medal_df = country_medals_df.groupby("Country")

grouped_country_medal_df.head()

# %%
grouped_country_medal_df.count()

# %%
# Group vehicles_df by both country and medal
 
g_country_medal_df = country_medals_df.groupby(["Country", "Medal"])

# %%
g_country_medal_df.head()

# %%
g_country_medal_df.count()

# %%
bsg_grouped = g_country_medal_df.count()

# %%
bsg_grouped.head()

# %%
gdp_medal_merged = pd.merge(bsg_grouped, countries_df, on="Country")

# %%
gdp_medal_merged.head()
